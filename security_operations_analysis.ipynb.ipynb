# %% [markdown]
# # 🔐 Security Operations Log Analysis
#
# > **Author:** Vandana Kumari
# > **Domain:** Cyber Security & Data Analytics
# > **Tools Used:** Python, Pandas, Jupyter Notebook
#
# ### Project Objective
# To analyze authentication logs and prepare clean, structured data for a
# Security Operations (SOC) dashboard.

# %% [markdown]
# ## 📌 Project Overview
#
# Organizations generate thousands of login records every day.
# Analyzing these logs manually is inefficient and error-prone.
#
# This project focuses on cleaning and preparing authentication log data
# to support a **Security Operations Dashboard** that helps identify:
# - Suspicious login behavior
# - High-risk users and IP addresses
# - Time-based attack patterns

# %% [markdown]
# importing libraries

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Vanda\OneDrive\Desktop\security-operations-dashboard\security_operations_dataset.csv")

# %% [markdown]
# CLEANING DATASET

# %%
# shape of the dataset
df.shape
# Out:
# (5000, 8)

# %%
# column names
df.columns
# Out:
# Index(['user_id', 'login_time', 'login_status', 'ip_address', 'country',
#        'device', 'os', 'browser'],
#       dtype='object')

# %%
# Data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       5000 non-null   object
#  1   login_time    5000 non-null   object
#  2   login_status  5000 non-null   object
#  3   ip_address    5000 non-null   object
#  4   country       5000 non-null   object
#  5   device        5000 non-null   object
#  6   os            5000 non-null   object
#  7   browser       5000 non-null   object
# dtypes: object(8)
# memory usage: 312.6+ KB

# %%
# chceking missing values
df.isnull().sum()
# Out:
# user_id         0
# login_time      0
# login_status    0
# ip_address      0
# country         0
# device          0
# os              0
# browser         0
# dtype: int64

# %% [markdown]
# ## 🧹 Removing Duplicate Records
#
# Duplicate login records can distort analysis and lead to incorrect security insights.
# These duplicates are identified and removed.

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# Confirm removal
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Convert login_time to datetime
df['login_time'] = pd.to_datetime(df['login_time'])

df.dtypes
# Out:
# user_id                 object
# login_time      datetime64[ns]
# login_status            object
# ip_address              object
# country                 object
# device                  object
# os                      object
# browser                 object
# dtype: object

# %%
# Drop rows with missing critical values
df.dropna(subset=[
    'user_id', 
    'login_time', 
    'login_status', 
    'ip_address'
], inplace=True)

# Check again
df.isnull().sum()
# Out:
# user_id         0
# login_time      0
# login_status    0
# ip_address      0
# country         0
# device          0
# os              0
# browser         0
# dtype: int64

# %%
# Standardize text columns
df['login_status'] = df['login_status'].str.strip().str.capitalize()
df['country'] = df['country'].str.strip().str.title()
df['device'] = df['device'].str.strip().str.capitalize()
df['os'] = df['os'].str.strip()
df['browser'] = df['browser'].str.strip()

df.head()
# Out:
#     user_id          login_time login_status      ip_address    country  \
# 0  user_164 2025-12-14 10:01:41      Success   80.125.114.71  Australia
# 1  user_152 2025-12-28 13:16:41      Success   33.111.119.13     Canada
# 2   user_57 2025-12-29 19:04:41      Success    217.3.81.216         Uk
# 3  user_196 2025-12-24 16:04:41      Success  107.49.183.176     Canada
# 4  user_138 2025-12-15 00:45:41       Failed  106.40.150.185     Canada
#
#     device       os  browser
# 0   Mobile    macOS   Chrome
# 1   Mobile    macOS   Safari
# 2  Desktop    Linux  Firefox
# 3  Desktop  Windows   Safari
# 4   Mobile  Windows   Chrome

# %%
# Unique login status values
df['login_status'].unique()
# Out:
# array(['Success', 'Failed'], dtype=object)

# %%
# Keep only valid statuses
df = df[df['login_status'].isin(['Success', 'Failed'])]

df['login_status'].value_counts()
# Out:
# login_status
# Success    3783
# Failed     1217
# Name: count, dtype: int64

# %%
df['date'] = df['login_time'].dt.date
df['hour'] = df['login_time'].dt.hour
df['day'] = df['login_time'].dt.day_name()
df['month'] = df['login_time'].dt.month_name()

df.head()
# Out:
#     user_id          login_time login_status      ip_address    country  \
# 0  user_164 2025-12-14 10:01:41      Success   80.125.114.71  Australia
# 1  user_152 2025-12-28 13:16:41      Success   33.111.119.13     Canada
# 2   user_57 2025-12-29 19:04:41      Success    217.3.81.216         Uk
# 3  user_196 2025-12-24 16:04:41      Success  107.49.183.176     Canada
# 4  user_138 2025-12-15 00:45:41       Failed  106.40.150.185     Canada
#
#     device       os  browser        date  hour        day     month
# 0   Mobile    macOS   Chrome  2025-12-14    10     Sunday  December
# 1   Mobile    macOS   Safari  2025-12-28    13     Sunday  December
# 2  Desktop    Linux  Firefox  2025-12-29    19     Monday  December
# 3  Desktop  Windows   Safari  2025-12-24    16  Wednesday  December
# 4   Mobile  Windows   Chrome  2025-12-15     0     Monday  December

# %%
# Define suspicious hours (late night)
df['late_night_login'] = df['hour'].apply(
    lambda x: 1 if x >= 0 and x <= 4 else 0
)

df['late_night_login'].value_counts()
# Out:
# late_night_login
# 0    4004
# 1     996
# Name: count, dtype: int64

# %%
# IP address length check
df['ip_address'].apply(len).describe()
# Out:
# count    5000.000000
# mean       13.336800
# std         1.101094
# min         9.000000
# 25%        13.000000
# 50%        13.000000
# 75%        14.000000
# max        15.000000
# Name: ip_address, dtype: float64

# %%
# Users count
df['user_id'].nunique()
# Out:
# 200

# %%
# Countries count
df['country'].nunique()
# Out:
# 7

# %%
df.shape
# Out:
# (5000, 13)

# %%
import os

os.makedirs("data", exist_ok=True)
df.to_csv("data/cleaned_login_logs.csv", index=False)

# %%
df.head()
# Out:
#     user_id          login_time login_status      ip_address    country  \
# 0  user_164 2025-12-14 10:01:41      Success   80.125.114.71  Australia
# 1  user_152 2025-12-28 13:16:41      Success   33.111.119.13     Canada
# 2   user_57 2025-12-29 19:04:41      Success    217.3.81.216         Uk
# 3  user_196 2025-12-24 16:04:41      Success  107.49.183.176     Canada
# 4  user_138 2025-12-15 00:45:41       Failed  106.40.150.185     Canada
#
#     device       os  browser        date  hour        day     month  \
# 0   Mobile    macOS   Chrome  2025-12-14    10     Sunday  December
# 1   Mobile    macOS   Safari  2025-12-28    13     Sunday  December
# 2  Desktop    Linux  Firefox  2025-12-29    19     Monday  December
# 3  Desktop  Windows   Safari  2025-12-24    16  Wednesday  December
# 4   Mobile  Windows   Chrome  2025-12-15     0     Monday  December
#
#    late_night_login
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 1
